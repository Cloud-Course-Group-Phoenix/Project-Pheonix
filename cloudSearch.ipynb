# %% [markdown]
# <a href="https://colab.research.google.com/github/Cloud-Course-Group-Phoenix/Project-Pheonix/blob/Daniel_Sasha_tirgul/cloudSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4
# !pip install firebase
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Collecting firebase
#   Downloading firebase-4.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from firebase) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->firebase) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->firebase) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->firebase) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->firebase) (2025.4.26)
# Downloading firebase-4.0.1-py3-none-any.whl (12 kB)
# Installing collected packages: firebase
# Successfully installed firebase-4.0.1

# %%
DBLink = "https://alexaanddaniel-c1413-default-rtdb.firebaseio.com/"

# %%
url = 'https://mqtt.org/'

# %%
import requests
import re
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from firebase import firebase

# קריאה לדף אינטרנט
def fetch_page(url):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            return soup
    except:
        return None
    return None

# ניקוי מילים
def clean_word(word):
    # משאיר רק אותיות באנגלית ומסנן תווים לא תקניים
    word = re.sub(r'[^a-zA-Z]', '', word)
    return word.lower()  # ממיר לאותיות קטנות

# חילוץ מילים
def index_words(soup):
    index = {}
    words = re.findall(r'\w+', soup.get_text())
    for word in words:
        word = clean_word(word)  # מנקה כל מילה
        if word and len(word) > 1:  # שואל אם המילה לא ריקה וגדולה מ-1 תו
            index[word] = index.get(word, 0) + 1
    return index

# הסרת מילים חסרות משמעות
def remove_stop_words(index):
    stop_words = {'a', 'an', 'the', 'and', 'or', 'in', 'on', 'at'}
    return {word: count for word, count in index.items() if word not in stop_words}

# בניית אינדקס הופכי (מילה -> רשימת דפים)
def add_to_inverted_index(inverted_index, index, doc_id):
    for word in index:
        if word not in inverted_index:
            inverted_index[word] = []
        if doc_id not in inverted_index[word]:
            inverted_index[word].append(doc_id)

# חילוץ קישורים פנימיים
def get_internal_links(soup, base_url, domain):
    links = set()
    for link_tag in soup.find_all('a', href=True):
        href = link_tag['href']
        full_url = urljoin(base_url, href)
        parsed = urlparse(full_url)
        if parsed.netloc == domain:
            cleaned_url = parsed.scheme + "://" + parsed.netloc + parsed.path
            links.add(cleaned_url)
    return links

# סריקה לעומק של האתר
def crawl_website(start_url):
    visited = set()
    to_visit = [start_url]
    domain = urlparse(start_url).netloc
    inverted_index = {}

    while to_visit:
        current_url = to_visit.pop()
        if current_url in visited:
            continue

        print(f"Scanning: {current_url}")
        soup = fetch_page(current_url)
        if soup is None:
            continue

        visited.add(current_url)

        # עיבוד המילים בדף
        index = index_words(soup)
        index = remove_stop_words(index)
        add_to_inverted_index(inverted_index, index, current_url)

        # מציאת קישורים פנימיים
        internal_links = get_internal_links(soup, current_url, domain)
        for link in internal_links:
            if link not in visited:
                to_visit.append(link)

    return inverted_index

# כתובת למסד הנתונים
DBLink = "https://alexaanddaniel-c1413-default-rtdb.firebaseio.com/"
firebase_conn = firebase.FirebaseApplication(DBLink, None)

# URL התחלתי
start_url = 'https://mqtt.org/'

# בניית האינדקס
inverted_index = crawl_website(start_url)

# הדפסת האינדקס למסך
print("\n=== Inverted Index ===")
for word, doc_list in inverted_index.items():
    print(f"{word} -> {doc_list}")

# העלאה ל-Firebase
firebase_conn.put('/', 'inverted_index', inverted_index)
print("\nSuccessfully uploaded to Firebase.")
# Out:
# Streaming output truncated to the last 5000 lines.
# kmmk -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jwf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# opg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zxks -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# nqr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
#
-> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fuqz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# nxd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mvuwf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gvr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ijs -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fkv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tdp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# npry -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# yxrk -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# asd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jfd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rui -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mlnm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zmtik -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# swy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pdaz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xcp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ifd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lzc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# guz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zrc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# truie -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# eyuf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wby -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# sot -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ntfb -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# igv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zypj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# aky -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# giri -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dguav -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hxi -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xup -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# duf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hkne -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jtyu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gwco -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hvkn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gpv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rky -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# efu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zxm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# loqf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zyud -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qewr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# iqcb -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pxjx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dek -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cize -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rimk -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lmm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# uzn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tqr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wzl -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# oitfvx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# iysyo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ocby -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gwke -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fovq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# prn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bhq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# maefx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# uixn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fvj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rhue -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rbut -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qfx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# htn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gfmgx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mlop -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lgd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gez -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# iawa -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tvkv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wku -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bqqr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mlb -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xfhc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ppc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bnff -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xsryn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bra -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# uog -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zuq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xde -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qgg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jkb -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rhp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# myq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lwm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dmn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rdn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hyj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ghf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hbw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rnyk -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# sezq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# glfz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# stc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-hor-neg.png']
# ljnaw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zgl -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hks -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hoaa -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wtyx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cas -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qon -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rvos -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xkv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dux -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hze -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mwju -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# unx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ezbf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tqfy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vjm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xcuv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zwd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ktn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ang -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gzw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xlu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lpe -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tkq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# swo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ttf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zmy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# copn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fto -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cfi -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# sed -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xpg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hcan -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rbz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mcc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# iuej -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fcg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dvc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# sgf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wml -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zhg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# opgri -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ted -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# etw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qmwc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lwx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# flf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# crg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tlu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zdj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# czes -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lfh -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qccw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# buz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xum -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wkv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mns -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cyac -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qcy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rzpa -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fpi -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-logo.png']
# gfrg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mgf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# oly -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# awwdat -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dmz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# sjw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# llf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tpz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cin -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xssau -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jyt -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fhwgm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mir -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# oaj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vbz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ymp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# iert -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fvm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ixp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dfx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rcn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vkr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-ver.png']
# frx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dqjq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# icf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ycl -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# plqh -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ethr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gbq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# kjvvgr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dyc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ljle -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hne -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# keh -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# yns -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lyea -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ekga -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ibz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gwann -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fkn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tgf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ypsq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ytd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lih -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zplo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ieo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# zbr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# oam -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wlj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# olsj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# kqd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jzf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# waq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wjy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# upp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# eun -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ydo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# heq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vkn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mzz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-hor-neg.png']
# clv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gks -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mnw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xwjj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xfwd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dgxm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vteuy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zzk -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ytn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tbjlp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dkd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wkl -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bhx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# srj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# djusd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ahy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pje -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hata -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pzl -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# arsq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ymq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bhv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hho -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wab -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gri -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vhh -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dwtz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# nslfo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vfp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ntt -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lzw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# mca -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# kwie -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rhym -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ddr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-ver.png']
# hgk -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xbr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ovai -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# irrj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# sta -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cdu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xzc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# awi -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xfy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ctp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hmz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# kor -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jzr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# due -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jbi -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gge -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ous -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# uyv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# aap -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# whe -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# axe -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bbs -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# klflbf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rjji -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# yvo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# moh -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cqd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vuz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fgua -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rxm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bcw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rur -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zun -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# yml -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# msc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# nmg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wjc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hwa -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xmy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zwoh -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# yuqu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# geo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ayu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wne -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ynju -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wtr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ligy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# flsgm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gff -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pvt -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ham -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zrv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# eii -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# nsv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zsx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dtw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wdska -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# czft -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# spc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rlkm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hfy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pwsy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# iej -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wvp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ghkop -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# oae -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cby -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ybnc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vjahg -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pot -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qbm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tsb -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tmv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# vzq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pummj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fgc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# wff -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cfxl -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ktnk -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qyu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zfz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tkr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# bmf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rod -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jmj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lmkx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# fkk -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ooo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xmz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jyp -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# yxh -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# hpovn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cfh -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ell -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# zyx -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pxc -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# yub -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# nygs -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# clta -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ktr -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# jkqy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# tbe -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qsz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# xrq -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# iwfn -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ymm -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# uua -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip', 'https://mqtt.org/assets/downloads/mqtt-hor-neg.png']
# jyd -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# gcab -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rjhj -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# uwl -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# lgy -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pstf -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# rsv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# pfb -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# czzo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# noeo -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# sue -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# uefbw -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# qof -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# kqnz -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# cpu -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ywul -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# dtv -> ['https://mqtt.org/assets/downloads/mqtt-logo-assets.zip']
# ...
# vmtx -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# yce -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# iko -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# grur -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# vkio -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# mazz -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# hmio -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# wwh -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# oiky -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# mkn -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# inio -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# ako -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# pkl -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# owi -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# uvzz -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# gom -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# vfzz -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# nvg -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# phi -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# aic -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# hsb -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# fhkon -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# kihk -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# pfzzf -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# tvwfk -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# arok -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# czzn -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# tzzh -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# pnzz -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# hja -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# cbjsv -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# nmp -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# iwb -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# gzz -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# lzg -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# fyro -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# qfiko -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# qsq -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# apn -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# ioj -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# isz -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# kya -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# azb -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# lias -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# lld -> ['https://mqtt.org/assets/downloads/mqtt-logo.png', 'https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# hhr -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# eooh -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# fjdk -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# uoy -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# wvwv -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# hzdv -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# gvu -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# fqn -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# pai -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# mkoci -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# uvwf -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# kwq -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# uvwfm -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# nxi -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# koik -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# ibg -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# eqo -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# konm -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# roeq -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# gqr -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# hunai -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# ael -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# wfqb -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# clx -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# kbk -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# iro -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# fmw -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# loz -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# kpk -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# siio -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# ikz -> ['https://mqtt.org/assets/downloads/mqtt-logo.png']
# soea -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# aucy -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# usi -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vtd -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# akmq -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# fql -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ynsx -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# eokt -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lhl -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mfa -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ufp -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# fmcahhl -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# pkoku -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# focc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# uqnwa -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# hsa -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# nbl -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# xnwa -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ruicc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# nccc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# nil -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mim -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# bul -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# dni -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vbvz -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# bhf -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# oyaf -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# meme -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# enf -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vnxy -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vnf -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vbit -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ihlpb -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ixh -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# pnb -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# iyt -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# pxdm -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mfzm -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lxq -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vowo -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# rxb -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# xrf -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lvm -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# pvnyr -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# scak -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# gcc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# nbvlb -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# otri -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# emee -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# nbv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# wgo -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# xoi -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# acc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# uxm -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# jsp -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# gts -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# hmow -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lvc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# isoo -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# glz -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# rkj -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# qiv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# igl -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# cpi -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ysim -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mkyh -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# giw -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ake -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ggtg -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ftwy -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# yuol -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# nokg -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mnd -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# szfwv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ych -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# nfk -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# dwv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# tzkgka -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# uhc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# zms -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vyk -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# xixv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# bdtg -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# qnca -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# htw -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# iqk -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ngan -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# xzg -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# xeg -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# xqwv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# qygs -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# fnv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# qtdt -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# iwi -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# xjp -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# fgfc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mox -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mmok -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# hkkgk -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mnsj -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# gnv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# grz -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# yuo -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# kokgk -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ihki -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# fzml -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# avct -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# iyq -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lis -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# dyi -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lxe -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# jwy -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# bny -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# pxpjj -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# yok -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vsbdg -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lrv -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# migok -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# wnz -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mwr -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vzgq -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vvk -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vvz -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lbc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# cnz -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ngk -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# rnghy -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# rlghy -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# alg -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# alo -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# gkhh -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# bcrsl -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mhg -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# lhk -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# vvy -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# eldo -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# fcyn -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# ano -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# iifj -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# jbq -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# sijl -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# bqu -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# cji -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# hju -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# mlh -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# hhoc -> ['https://mqtt.org/assets/downloads/mqtt-ver-neg.png']
# what -> ['https://mqtt.org/faq/']
# constrained -> ['https://mqtt.org/faq/']
# minimise -> ['https://mqtt.org/faq/']
# requirements -> ['https://mqtt.org/faq/']
# whilst -> ['https://mqtt.org/faq/']
# attempting -> ['https://mqtt.org/faq/']
# ensure -> ['https://mqtt.org/faq/']
# degree -> ['https://mqtt.org/faq/']
# assurance -> ['https://mqtt.org/faq/']
# turn -> ['https://mqtt.org/faq/']
# where -> ['https://mqtt.org/faq/']
# battery -> ['https://mqtt.org/faq/']
# premium -> ['https://mqtt.org/faq/']
# who -> ['https://mqtt.org/faq/']
# invented -> ['https://mqtt.org/faq/']
# andy -> ['https://mqtt.org/faq/']
# stanford -> ['https://mqtt.org/faq/']
# clark -> ['https://mqtt.org/faq/']
# arcom -> ['https://mqtt.org/faq/']
# since -> ['https://mqtt.org/faq/']
# interesting -> ['https://mqtt.org/faq/']
# examples -> ['https://mqtt.org/faq/']
# ratified -> ['https://mqtt.org/faq/']
# there -> ['https://mqtt.org/faq/']
# ports -> ['https://mqtt.org/faq/']
# reserved -> ['https://mqtt.org/faq/']
# iana -> ['https://mqtt.org/faq/']
# registered -> ['https://mqtt.org/faq/']
# does -> ['https://mqtt.org/faq/']
# pass -> ['https://mqtt.org/faq/']
# name -> ['https://mqtt.org/faq/']
# password -> ['https://mqtt.org/faq/']
# packet -> ['https://mqtt.org/faq/']
# handled -> ['https://mqtt.org/faq/']
# independently -> ['https://mqtt.org/faq/']
# itself -> ['https://mqtt.org/faq/']
# worth -> ['https://mqtt.org/faq/']
# noting -> ['https://mqtt.org/faq/']
# lightest -> ['https://mqtt.org/faq/']
# significant -> ['https://mqtt.org/faq/']
# overhead -> ['https://mqtt.org/faq/']
# added -> ['https://mqtt.org/faq/']
# encrypting -> ['https://mqtt.org/faq/']
# sends -> ['https://mqtt.org/faq/']
# receives -> ['https://mqtt.org/faq/']
# something -> ['https://mqtt.org/faq/']
# keep -> ['https://mqtt.org/faq/']
# find -> ['https://mqtt.org/faq/']
# ask -> ['https://mqtt.org/faq/']
# questions -> ['https://mqtt.org/faq/']
# methods -> ['https://mqtt.org/faq/']
# stackoverflow -> ['https://mqtt.org/faq/']
# terms -> ['https://mqtt.org/faq/']
# acronyms -> ['https://mqtt.org/faq/']
# routes -> ['https://mqtt.org/faq/']
# published -> ['https://mqtt.org/faq/']
# lwt -> ['https://mqtt.org/faq/']
# last -> ['https://mqtt.org/faq/']
# testament -> ['https://mqtt.org/faq/']
# working -> ['https://mqtt.org/faq/']
#
# האינדקס הועלה בהצלחה ל-Firebase.
